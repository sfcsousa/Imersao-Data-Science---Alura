# %% [markdown]
# <a href="https://colab.research.google.com/github/sfcsousa/Imersao-Data-Science---Alura/blob/main/Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 01

# %%
10+10
# Out:
# 20

# %%
"Pedro Sousa"
# Out:
# 'Pedro Sousa'

# %%
import pandas as pd
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
base_dados = pd.read_csv(url_dados, compression = 'zip')
base_dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
base_dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
base_dados.shape
# Out:
# (23814, 877)

# %%
#cada linha é um experimento
# com droga e com controle, 
# cada linha é uma cultura de celula que foi submetida a uma droga

# %%
base_dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)

# %%
base_dados['tratamento'] ## serie:  conjunto de dados de uma coluna do dataframe
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
base_dados['tratamento'].unique() ## identifica os valores unicos que aparecem em uma seia em especifico
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
base_dados['tempo'].unique() # o tempo do qual o sujeito ficou exposto ao fármaco
# Out:
# array([24, 72, 48])

# %%
base_dados['dose'].unique() # as doses que foram utilizadas
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
drogas = base_dados['droga'].unique() ## a nomenclatura é lista, mas o objeto é um array.
drogas
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
base_dados['tempo'].value_counts() ## conta os valores que se repetem na série
# Out:
# 48    8250
# 72    7792
# 24    7772
# Name: tempo, dtype: int64

# %%
base_dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 1d39c75d6       1
# 36dc71f82       1
# 225385f09       1
# d532d49de       1
# b6b4f212d       1
# Name: droga, Length: 3289, dtype: int64

# %%
base_dados['tratamento'].value_counts() ## aspas simples ou duplas, não tem diferença no python
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
base_dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
base_dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
base_dados["tratamento"].value_counts().plot.pie()

# %%
base_dados['tempo'].value_counts().plot.pie()

# %%
base_dados['tempo'].value_counts(normalize = True)  ## Sempre evitar gráficos de pizza, o que for de comer,
                                                    ## normalmente não é o melhor para analisar
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
base_dados['tempo'].value_counts().plot.bar()

# %%
base_dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados_maior_zero = base_dados[base_dados['g-0'] > 0 ] 

dados_maior_zero.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 01: Investigar o por que a classe tratamento é tão desbalanceada

# %% [markdown]
# É visto que há um desbalanceamento na série tratamento pelo falo que de as amostras com_controle são amostras de controle, que servem com o parâmetro de comparação com a reação das outras amostras.

# %%
print(f"Total de dados {len(base_dados['id'])}\n")
print(f"Quantidade de drogas {len(base_dados.groupby(['droga', 'tratamento']).count()['id'])}\n")
display(base_dados.query('tratamento == "com_controle"').value_counts('droga'))
print()
print('Visto, então, que a droga cacb2b860 foi a utilizada como parâmetro base de controle do experimento')
print()
display(base_dados.query('droga == "cacb2b860"').value_counts('tratamento'))
print()
display(base_dados.query('droga != "cacb2b860"').value_counts('tratamento'))
print()
display(base_dados.query('tratamento != "com_controle"').value_counts('droga'))
# Out:
# Total de dados 23814
#
# Quantidade de drogas 3289
# droga
# cacb2b860    1866
# dtype: int64
# Visto, então, que a droga cacb2b860 foi a utilizada como parâmetro base de controle do experimento
# tratamento
# com_controle    1866
# dtype: int64
# tratamento
# com_droga    21948
# dtype: int64
# droga
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 153840764      1
# 36dc71f82      1
# 1502f8cbb      1
# b472193a9      1
# 67c4672f3      1
# Length: 3288, dtype: int64

# %% [markdown]
# ### Desafio 02: Plotar as 5 útimas linhas da tabela

# %%
base_dados.tail() ##tail retorna as ultimas 5 linhas
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 03: Proporção das classes tratamento

# %%
base_dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# ### Desafio 04 : Quantos Tipos de Drogas foram investigadas?

# %%
drogas_count = base_dados["droga"].value_counts()
drogas_count
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 1d39c75d6       1
# 36dc71f82       1
# 225385f09       1
# d532d49de       1
# b6b4f212d       1
# Name: droga, Length: 3289, dtype: int64

# %%
drogas_count.count()
# Out:
# 3289

# %% [markdown]
# ### Desafio 05: Procurar na documentação o método query do pandas

# %%
base_dados.query('dose == "D1" and tempo == 72 and tratamento == "com_controle"')

## o método query recebe expressoes que devem retornar boleanos, onde o true dessa expressão irá montar o DF resultante
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 81     id_00d575cfb  com_controle     72   D1  ...  0.6034  0.8906  1.0350  0.5739
# 175    id_01f1c58a2  com_controle     72   D1  ...  0.2932  0.7680 -0.1686  0.1007
# 413    id_046098431  com_controle     72   D1  ... -0.1745 -0.4871  1.2200  0.5859
# 552    id_05bd7e0e4  com_controle     72   D1  ...  0.6595 -0.0360  1.2900 -0.4990
# 637    id_067111b8e  com_controle     72   D1  ...  0.2380 -0.0960  0.5891  0.0400
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23131  id_f88522f85  com_controle     72   D1  ... -0.3868 -0.4131  0.5946  0.8983
# 23137  id_f88e9fbf2  com_controle     72   D1  ... -0.3723  0.7377  0.4391  0.7195
# 23147  id_f89f99adb  com_controle     72   D1  ...  0.4386  0.7585  0.2623  0.7413
# 23303  id_fa63d0a94  com_controle     72   D1  ... -0.0322  0.1511  0.5358  0.5088
# ...

# %%
# ?pd.DataFrame.query

# %% [markdown]
# ### Desafio 06: Procurar na documentação como deixar os gráficos melhores (matplotlib)

# %%
base_dados['tempo'].value_counts().plot.bar( title = "Amostras por Tempo ", rot = 0, ylabel = 'Quantidade Amostrastop')

# %% [markdown]
# ### Desafio 07: Renomear as Colunas, retirando o hifen

# %%
base_dados.columns = base_dados.columns.str.replace('-','')
base_dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# - É visto que a análise dos dados depende e muito do conhecimento do negócio, sem isso, ainda falta um pouco de direção para onde investigar.
#
# - Visto que 3289 drogas foram testadas nessa base de dados.
#
# - Suspeito que cada droga tenha uma relação diferente com o gene no tempo.
#
# - Ansioso para entender melhor o matplotlib, apresentação é o que encanta.

# %% [markdown]
# # Aula 02

# %%
base_dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {
    'droga':'composto'
}
base_dados.rename(columns=mapa, inplace=True) 
# o parametro inplace=True substitui os atributes na própria referencia do objeto, com isso mudas todas as chamadas
base_dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
base_dados['composto'].value_counts().head()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
## poderia ser feito na seguinte nomenclatura
base_dados['composto'].value_counts()[:5]
base_dados['composto'].value_counts()[0:5] # a partir do elemento 0, pegar as 5 posições
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
# Name: composto, dtype: int64

# %%
compostos_head = base_dados['composto'].value_counts().index[:5]
compostos_head
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
base_dados.query('composto in @compostos_head') #selecionar da series, o que está contido na variável
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8)) # eixo x e eixo y. figsize é um parametro que recebe uma pupunha (x, y)
# o countplot ele alem de apresentar, ele conta com base nos dados
sns.countplot(data= base_dados.query('composto in @compostos_head'), x= 'composto').set_title('Top 5 compostos') 
## o python ele declara os parametros de função default, utilzando essa nomenclatura
# x = 'composto' define o eixo x do grafico as a coluna composto
# é possivel chamar a query direto no parametro
# Out:
# Text(0.5, 1.0, 'Top 5 compostos')

# %%
# Melhores Praticas
# o figure vindo anteriormente é relacionado ao gráfico da sequencia
plt.figure(figsize=(10,8))
ax = sns.countplot(data= base_dados.query('composto in @compostos_head'), x= 'composto')
ax.set_title('Top 5 Compostos')
plt.show()

# %%
# analise dos genes
base_dados['g0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
len(base_dados['g0'].unique())
# Out:
# 14367

# %%
base_dados['g0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g0, dtype: float64

# %%
#histogram, o bins define a quantidade de agrupadores no histograma
base_dados['g0'].hist(bins = 100)

# %%
base_dados['g19'].hist(bins = 100)

# %%
base_dados['g3'].describe()
# Out:
# count    23814.000000
# mean         0.081971
# std          0.950012
# min         -5.998000
# 25%         -0.429575
# 50%          0.008050
# 75%          0.463400
# max         10.000000
# Name: g3, dtype: float64

# %%
base_dados[['g0','g1']].describe()
# Out:
#                  g0            g1
# count  23814.000000  23814.000000
# mean       0.248366     -0.095684
# std        1.393399      0.812363
# min       -5.513000     -5.737000
# 25%       -0.473075     -0.562200
# 50%       -0.008850     -0.046600
# 75%        0.525700      0.403075
# max       10.000000      5.039000

# %%
base_dados.loc[0:,'g0']# do 1o elemento até o ultimo da serie
base_dados.loc[:,'g0':'g771']
# Out:
#            g0      g1      g2      g3  ...    g768    g769    g770    g771
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  0.3008  1.6490  0.2968 -0.0224
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.1626 -0.3340 -0.3289 -0.2718
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.5797  0.3143  0.8133  0.7923
# 3     -0.5138 -0.2491 -0.2656  0.5288  ...  0.1996  0.4374  0.1588 -0.0343
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -1.0020 -0.7534  0.5000 -0.6269
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.7221  0.5099 -0.1423  0.3806
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  0.5247  0.5438 -0.1875 -0.4751
# 23811  0.3942  0.3756  0.3109 -0.7389  ...  0.9778  0.2326 -0.6191  0.3603
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.1794  0.3109 -0.3491 -0.4741
# 23813 -0.8598  1.0240 -0.1361  0.7952  ...  1.5410  0.3633 -3.1970  2.2190
#
# [23814 rows x 772 columns]

# %%
base_dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
#transpor a minha tabela, invertendo a matriz
base_dados.loc[:,'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
base_dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=40)

# %%
base_dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=40)

# %%
base_dados.loc[:,'g0':'g771'].describe().T['50%'].hist(bins=40)

# %%
#Analise dos C, uma linhagem de um tipo celular
base_dados.loc[:,'c0':'c99'].describe().T
# Out:
#        count      mean       std   min       25%      50%       75%    max
# c0   23814.0 -0.355156  1.752565 -10.0 -0.549300 -0.00900  0.448975  3.365
# c1   23814.0 -0.455359  2.004962 -10.0 -0.538425  0.00980  0.476875  3.915
# c2   23814.0 -0.480542  2.039346 -10.0 -0.550375 -0.00400  0.460575  2.970
# c3   23814.0 -0.377666  1.554583 -10.0 -0.601975 -0.03905  0.413100  2.408
# c4   23814.0 -0.493552  2.091888 -10.0 -0.559975  0.01140  0.470300  4.555
# ..       ...       ...       ...   ...       ...      ...       ...    ...
# c95  23814.0 -0.353726  1.629291 -10.0 -0.567975 -0.01025  0.444750  2.814
# c96  23814.0 -0.463485  2.059725 -10.0 -0.552575 -0.00125  0.465225  3.505
# c97  23814.0 -0.378241  1.703615 -10.0 -0.561000 -0.00680  0.446400  2.924
# c98  23814.0 -0.470252  1.834828 -10.0 -0.592600  0.01400  0.461275  3.111
# c99  23814.0 -0.301505  1.407918 -10.0 -0.562900 -0.01950  0.438650  3.805
#
# [100 rows x 8 columns]

# %%
base_dados.loc[:,'c0':'c99'].describe().T['50%'].hist(bins=40)

# %%
base_dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=40)

# %%
sns.boxplot(x= 'g0',data= base_dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x= 'g0', y = 'tratamento',data= base_dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y= 'g0', x = 'tratamento',data= base_dados)

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafio 01 Ordenar o grafico countplot do maior para o menor, ou vice e versa

# %%
print(compostos_head)
print()
print(base_dados.query('composto in @compostos_head'))
print()
print(base_dados.query('composto in @compostos_head')['composto'].value_counts())
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')
#
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(data= base_dados.query('composto in @compostos_head'), x= 'composto', order = compostos_head)
ax.set_title('Top 5 Compostos')
ax.set(xlabel='Composto' , ylabel='Contagem')
plt.show()

# %% [markdown]
# ### Desafio 02 Melhorar as fontes das legendas dos eixos para facilitar a visualização (seaborne)
# ### Verificar como plotar mais de um gráfico do lado do outro

# %%
base_transportada = base_dados.loc[:,'g0':'g771'].describe().T
base_T_mean = base_transportada['mean']
base_T_median = base_transportada['50%']

# %%
base_T_mean.hist(bins=30)

# %%
base_T_median.hist(bins=30)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
fig.suptitle('Comparativo de media e mediana dos genes 0 e 771')

base_T_median.hist(bins=30, ax=ax1)
base_T_mean.hist(bins=30, ax=ax2)
plt.show()

# %% [markdown]
# ###Desafio 03 Plotar os histogramas com o Seaborn

# %%
sns.histplot(data=base_transportada, x='mean', kde=True)

# %%
plt.figure(figsize=(10,8))
ax = sns.histplot(data=base_transportada, x='mean', fill=False)
ax.set_title('Histograma da quantidade de vezes que a média aparece')
ax.set_xlabel("Média da distribuição da média entre os genes")
ax.set_ylabel("Quantidade")
plt.show()

# %% [markdown]
# ### Desafio 04 Estudar sobre as estatisticas retornadas no método describe

# %%
base_dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# Segundo documentação, o describe resume as tendências centrais do dataframe que está sendo analisado, trazendo informações sobre disperção e formato da distribuição da base.
# Informações de analise da massa como média e mediana, além dos 1o e 3o quartis.
# Além dessas informações, com o count, min e max, podemos visualizar respectivamente o tamanho da amostra e os valores mínimos e máximos, nos dando uma ideia de amplitude.

# %% [markdown]
# ### Desafio 05 Refletir sobre a manipulação dos tamanhos das visualizações.

# %% [markdown]
# A importância na visualização de um gráfico está completamente relacionada a comunicação entre o loucutor e ouvinte. O gráfico ele deve transmitir a informação tratada e analisada de forma que o ouvinte, a audiência capte a informação apresentada, como em uma conversa que flui normalmente.
#
# Atributos como cor, tamanho da fonte, estilo da fonte, legendas, espaçamento, contribuem para facilitar(ou não) essa comunicação e transmissão da informação.

# %% [markdown]
# ### Desafio 06: Realizar outras análises com o boxplots e histogramas

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='dose' , data=base_dados)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='tempo' , data=base_dados)
plt.title('Resultado de G0 no tempo')
plt.xlabel('Período de tempo')
plt.show()

# %%
plt.figure(figsize=(10,7))
ax = sns.histplot(data=base_dados,x= 'g2', bins=90,hue='tratamento')
plt.title('Contagem de Valores de variação de g-2')
plt.show()

# %% [markdown]
# ### Desafio 07: Resumo do que eu aprendi com os dados
#
# Vejo que conforme estamos nos aprofundando na análise da base e encontrando novos recursos para nos apoiar nessa análise, fica claro a relação de estímulo que cada droga tem com o gene específico.

# %% [markdown]
# # Aula 03

# %%
base_dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## criando uma tabela de frenquencia para cruzar as informações
pd.crosstab(base_dados['dose'],base_dados['tempo'])
# esta visualização apresenta um cruzamento de dois paramtros, nesse caso, ele conta um, com o outro
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'])
#parametro da esquerda, series que irão definir as linhas e parametro da direita o que irá definir a coluna.
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'],normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'],normalize='index')
# o parametro normalize ='index' faz com que o contraste seja referenciado ao indice da linha.
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'],normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'], values=base_dados['g0'],aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'], values=base_dados['g0'],aggfunc='median')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %%
plt.figure(figsize=(10,8))
ax = sns.scatterplot(x='g0',y= 'g3',data=base_dados)
ax.set_title('Correlação entre g0 e g3')
plt.show()

# %%
base_dados[['g0','g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
base_dados[['g0','g8']].tail()
# Out:
#            g0      g8
# 23809  0.1394 -0.4726
# 23810 -1.3260  0.5112
# 23811  0.3942 -0.0340
# 23812  0.6660  0.4299
# 23813 -0.8598  3.0790

# %%
plt.figure(figsize=(10,8))
ax = sns.scatterplot(x='g0',y= 'g8',data=base_dados)
ax.set_title('Correlação entre g0 e g8')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lmplot(data=base_dados,x='g0',y='g8',line_kws={'color':'red'})
plt.show()

# %%
sns.lmplot(data=base_dados,x='g0',y='g8',line_kws={'color':'red'}, col='tratamento')

# %%
sns.lmplot(data=base_dados,x='g0',y='g8',line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
base_dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
## Valores próximos a -1, são correlacionadas inversamente proporcionais, já valores próximos a 1, são correlacionados proporcionamente
# já os próximos a 0, não tem correlação tão forte.

# %%
from string import ascii_letters
import numpy as np

# %%
# Compute the correlation matrix
corr = base_dados.loc[:,'g0':'g50'].corr()

# %%
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
corr_celulas = base_dados.loc[:,'c0':'c50'].corr()
sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celulas, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celulas, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ##Desafios

# %% [markdown]
# ### Desafio 01: Criar tabelas de frequência com o pandas.groupby()

# %%
pd.crosstab([base_dados['dose'], base_dados['tempo']],  base_dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([base_dados['dose'], base_dados['tempo']],  base_dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
com_droga = base_dados.query('tratamento=="com_droga"').groupby(['dose','tempo']).count()['tratamento']

# %%
com_controle = base_dados.query('tratamento=="com_controle"').groupby(['dose','tempo']).count()['tratamento']

# %%
com_droga
# Out:
# dose  tempo
# D1    24       3585
#       48       4011
#       72       3600
# D2    24       3581
#       48       3591
#       72       3580
# Name: tratamento, dtype: int64

# %%
com_controle
# Out:
# dose  tempo
# D1    24       301
#       48       343
#       72       307
# D2    24       305
#       48       305
#       72       305
# Name: tratamento, dtype: int64

# %%
tb_frequencia = pd.concat([com_controle,com_droga],axis=1)
tb_frequencia
# Out:
#             tratamento  tratamento
# dose tempo
# D1   24            301        3585
#      48            343        4011
#      72            307        3600
# D2   24            305        3581
#      48            305        3591
#      72            305        3580

# %%
tb_frequencia.columns = ['com controle', 'com droga']
tb_frequencia
# Out:
#             com controle  com droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
tb_frequencia.div(tb_frequencia.sum(axis=1),axis=0)
# Out:
#             com controle  com droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# ### Desafio 02: Normalizar o crossTab pela coluna

# %%
pd.crosstab([base_dados['dose'],base_dados['tempo']],base_dados['tratamento'],normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ### Desafio 03: Explorar outros agregadores para o crosstab

# %%
pd.crosstab([base_dados['dose'], base_dados['tempo']],  base_dados['tratamento'], values=base_dados['g0'], aggfunc='last')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           0.0465     0.6660
#      48           1.1120     0.1420
#      72          -0.6204    -0.8598
# D2   24           0.7200    -1.3260
#      48           0.3942    -0.1150
#      72          -0.1051    -0.4330

# %%
pd.crosstab([base_dados['dose'], base_dados['tempo']],  base_dados['tratamento'], values=base_dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
pd.crosstab([base_dados['dose'], base_dados['tempo']],  base_dados['tratamento'], values=base_dados['g0'], aggfunc='median')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %% [markdown]
# ### Desafio 04: Explorar o melt.

# %%
pd.melt(base_dados,id_vars=['tempo'],value_vars=['g0'])
# Out:
#        tempo variable   value
# 0         24       g0  1.0620
# 1         72       g0  0.0743
# 2         48       g0  0.6280
# 3         48       g0 -0.5138
# 4         72       g0 -0.3254
# ...      ...      ...     ...
# 23809     24       g0  0.1394
# 23810     24       g0 -1.3260
# 23811     48       g0  0.3942
# 23812     24       g0  0.6660
# 23813     72       g0 -0.8598
#
# [23814 rows x 3 columns]

# %%
pd.melt(base_dados,id_vars=['tempo','dose'],value_vars=['g0']).tail()
# Out:
#        tempo dose variable   value
# 23809     24   D2       g0  0.1394
# 23810     24   D2       g0 -1.3260
# 23811     48   D2       g0  0.3942
# 23812     24   D1       g0  0.6660
# 23813     72   D1       g0 -0.8598

# %%
pd.melt(base_dados,id_vars=['tempo','dose'],value_vars=['g0'])
# Out:
#        tempo dose variable   value
# 0         24   D1       g0  1.0620
# 1         72   D1       g0  0.0743
# 2         48   D1       g0  0.6280
# 3         48   D1       g0 -0.5138
# 4         72   D2       g0 -0.3254
# ...      ...  ...      ...     ...
# 23809     24   D2       g0  0.1394
# 23810     24   D2       g0 -1.3260
# 23811     48   D2       g0  0.3942
# 23812     24   D1       g0  0.6660
# 23813     72   D1       g0 -0.8598
#
# [23814 rows x 4 columns]

# %% [markdown]
# ### Desafio 05: Calcular e analisar a correlaçãpo entre G e C. Refletir sobre os efeitos biologicos

# %%
corr =  base_dados.loc[: , 'g0':'c99'].corr()
corr_genes_celulas = corr.loc['g0':'g50','c0':'c50']
corr_genes_celulas
# Out:
#            c0        c1        c2  ...       c48       c49       c50
# g0  -0.624116 -0.624810 -0.639789  ... -0.595291 -0.609109 -0.594011
# g1  -0.037405 -0.030558 -0.039616  ... -0.006228  0.027230  0.017267
# g2  -0.168656 -0.178692 -0.176733  ... -0.160305 -0.167884 -0.153191
# g3  -0.037342 -0.093505 -0.085298  ... -0.058527 -0.033818 -0.012714
# g4  -0.403545 -0.379840 -0.392841  ... -0.349730 -0.349804 -0.360544
# g5   0.209358  0.198890  0.211988  ...  0.193371  0.192872  0.194516
# g6  -0.103316 -0.079528 -0.078782  ... -0.050473 -0.086187 -0.078581
# g7   0.486478  0.553859  0.565002  ...  0.559356  0.531681  0.516563
# g8   0.621422  0.601678  0.597372  ...  0.513047  0.560689  0.547889
# g9   0.435235  0.475424  0.488331  ...  0.463612  0.458629  0.451328
# g10  0.586035  0.643461  0.640281  ...  0.598668  0.598015  0.592971
# g11 -0.231425 -0.270409 -0.276064  ... -0.254556 -0.229148 -0.226246
# g12  0.345752  0.361244  0.357949  ...  0.340069  0.346491  0.354359
# ...

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_genes_celulas, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
sns.lmplot(data=base_dados
           , x='g20', y='c13', line_kws={'color': 'orange'})

# %%
sns.lmplot(data=base_dados
           , x='g38', y='c13', line_kws={'color': 'orange'})

# %%
sns.lmplot(data=base_dados
           , x='g43', y='c13', line_kws={'color': 'orange'})

# %% [markdown]
# ### Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)

# %%
sns.set_theme(style="white")

# Gera uma matriz de true, para o df de correlação e cria uma mascara para o triangulo superior
mask = np.triu(np.ones_like(corr_celulas, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap // Paleta de cores
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celulas, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 07:
#   Visto que os genes e as celulas tem diversos tipos de relações entre si, e o que mais é impactante são as relações entre os comportamentos celular, que é positivo e proporcional.
